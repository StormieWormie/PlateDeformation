# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import FiniteDifferenceMethod as FDM 
import FiniteElementMethod as FEM

# %%
from Python_wrapper import *

# %%
Source = -1
Clamp_height = 0
Clamp_tangent = 0
N = 40

# %%
data, positions, results = Run_all(Source, Clamp_height, Clamp_tangent, N)
# Out:
# Solving succes!
# Solving succes!
# Solving succes!
# Solving succes!

# %%
X = positions[:,0]
Y = positions[:,1]

fig=plt.figure(figsize=(10,10))    
ax = fig.add_subplot(2,2,1,projection='3d')
ax.plot_trisurf(X, Y, results["fdm_fast"])
ax.set_title("fdm_fast")
ax = fig.add_subplot(2,2,2,projection='3d')
ax.plot_trisurf(X, Y, results["fdm_accurate"])
ax.set_title("fdm_accurate")
ax = fig.add_subplot(2,2,3,projection='3d')
ax.plot_trisurf(X, Y, results["fem_mixed"])
ax.set_title("fem_mixed")
ax = fig.add_subplot(2,2,4,projection='3d')
ax.plot_trisurf(X, Y, results["fem_exotic"])
ax.set_title("fem_exotic")
# Out:
# Text(0.5, 0.92, 'fem_exotic')
